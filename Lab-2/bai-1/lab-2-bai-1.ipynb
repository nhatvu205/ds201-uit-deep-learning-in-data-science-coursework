# %% [markdown]
# # BÀI THỰC HÀNH 2: MẠNG NEURAL TÍCH CHẬP

# %% [markdown]
# <b>Hướng dẫn nộp bài:</b> Các bạn commit và push code lên github, sử dụng file txt đặt tên theo cú pháp <MSSV>.txt chứa đường link dẫn đến github của bài thực hành và nộp file txt này tên courses.
#
# Bộ dữ liệu sử dụng: [MNIST dataset](https://git-disl.github.io/GTDLBench/datasets/mnist_datasets/) (bài 1) và [VinaFood21 dataset](https://arxiv.org/abs/2108.02929) (các bài còn lại).
#
# Link download: https://drive.google.com/file/d/1UpZOf0XlwvB4rKpyZ35iwTA8oWHqDBbR/view?usp=share_link.

# %% [markdown]
# ### Bài 1: Xây dựng mô hình LeNet. Huấn luyện và đánh giá mô hình LeNet trên 4 độ đo precision, recall và F1-macro (sử dụng Adam làm optimizer).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install idx2numpy

# %%
import os
os.chdir("/content/drive/MyDrive/Uni/Ki-5-Nam-3/DS201/Lab-2/bai-1")
os.getcwd()
# Out:
# '/content/drive/MyDrive/Uni/Ki-5-Nam-3/DS201/Lab-2/bai-1'

# %%
# %run main.py
# Out:
# Device: cpu
# Train: 54000, Val: 6000
# Test: 10000
# Epoch 1: 100%|██████████| 844/844 [00:25<00:00, 32.52it/s, loss=0.376, acc=88.3]
# Epoch 1/10 - Train Loss: 0.3765, Train Acc: 88.27% | Val Loss: 0.1520, Val Acc: 95.50%
# Epoch 2: 100%|██████████| 844/844 [00:22<00:00, 38.11it/s, loss=0.114, acc=96.5]
# Epoch 2/10 - Train Loss: 0.1143, Train Acc: 96.52% | Val Loss: 0.0971, Val Acc: 97.22%
# Epoch 3: 100%|██████████| 844/844 [00:22<00:00, 38.17it/s, loss=0.0791, acc=97.6]
# Epoch 3/10 - Train Loss: 0.0791, Train Acc: 97.56% | Val Loss: 0.0774, Val Acc: 97.60%
# Epoch 4: 100%|██████████| 844/844 [00:22<00:00, 37.01it/s, loss=0.0631, acc=98]
# Epoch 4/10 - Train Loss: 0.0631, Train Acc: 98.04% | Val Loss: 0.0800, Val Acc: 97.57%
# Epoch 5: 100%|██████████| 844/844 [00:20<00:00, 40.84it/s, loss=0.0514, acc=98.3]
# Epoch 5/10 - Train Loss: 0.0514, Train Acc: 98.31% | Val Loss: 0.0682, Val Acc: 98.02%
# Epoch 6: 100%|██████████| 844/844 [00:22<00:00, 37.49it/s, loss=0.0432, acc=98.6]
# Epoch 6/10 - Train Loss: 0.0432, Train Acc: 98.62% | Val Loss: 0.0661, Val Acc: 98.00%
# Epoch 7: 100%|██████████| 844/844 [00:21<00:00, 39.36it/s, loss=0.0378, acc=98.8]
# Epoch 7/10 - Train Loss: 0.0378, Train Acc: 98.84% | Val Loss: 0.0643, Val Acc: 98.03%
# Epoch 8: 100%|██████████| 844/844 [00:23<00:00, 36.62it/s, loss=0.033, acc=99]
# Epoch 8/10 - Train Loss: 0.0330, Train Acc: 98.96% | Val Loss: 0.0492, Val Acc: 98.52%
# Epoch 9: 100%|██████████| 844/844 [00:21<00:00, 39.30it/s, loss=0.0281, acc=99.1]
# Epoch 9/10 - Train Loss: 0.0281, Train Acc: 99.15% | Val Loss: 0.0631, Val Acc: 98.15%
# Epoch 10: 100%|██████████| 844/844 [00:22<00:00, 37.94it/s, loss=0.0256, acc=99.2]
# Epoch 10/10 - Train Loss: 0.0256, Train Acc: 99.21% | Val Loss: 0.0507, Val Acc: 98.45%
#
# Evaluation Results:
# Accuracy: 98.97%
# Precision (macro): 0.9897
# Recall (macro): 0.9896
# F1-Score (macro): 0.9896
#
# Per-class results:
# Class      Precision    Recall       F1-Score
# 0          0.9949       0.9939       0.9944
# 1          0.9947       0.9956       0.9952
# 2          0.9885       0.9952       0.9918
# 3          0.9901       0.9901       0.9901
# 4          0.9879       0.9949       0.9914
# 5          0.9866       0.9899       0.9882
# 6          0.9906       0.9885       0.9896
# 7          0.9743       0.9961       0.9851
# 8          0.9907       0.9867       0.9887
# 9          0.9990       0.9653       0.9819
